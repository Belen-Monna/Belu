# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <H1> "My Jupyter Notebook on IBM Watson Studio" <H1>

# %% [markdown]
# **Belen**
#
#
# Data Science

# %% [markdown]
# <H3> Debe ejecutarse y debe mostrar una salida.<H3>

# %% [markdown]
# | Nombre  | Apellido  |
# |---------|-----------|
# | Belen   | Monna     |
# | Emmanuel| Bartolini |
#
# [ Datos de la Luna ](https://es.wikipedia.org/wiki/Luna)
#
#
# ![Coursera](https://play.google.com/store/apps/details?id%3Dorg.coursera.android%26hl%3Dit%26gl%3DUS)
#
# ---
# Hola
# ---
